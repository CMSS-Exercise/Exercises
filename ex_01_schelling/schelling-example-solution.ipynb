# %% [markdown]
# # Mesa Schelling example - A Schelling-like Segregation Model
#
# ## Description
#
# The Schelling (1971) segregation model is a classic of agent-based modeling, demonstrating how agents following simple rules lead to the emergence of qualitatively different macro-level outcomes. Agents are randomly placed on a grid. There are two types of agents, one constituting the majority and the other the minority. All agents want a certain number (generally, 3) of their 8 surrounding neighbors to be of the same type in order for them to be happy. Unhappy agents will move to a more happier grid space (if available). While individual agents do not have a preference for a segregated outcome (e.g. they would be happy with 3 similar neighbors and 5 different ones), the aggregate outcome can nevertheless become heavily segregated.
#
# ## Sample Model Description
#
# The tutorial model is a very simple simulated dynamic of agent segregation. These are the rules of our tutorial model:
#
# 1. There are some number of agents.
# 2. All agents begin as randomly placed on a grid.
# 3. At every step of the model, an agent considers how many of its surrounding neighbors to be of the same type in order for them to be happy.
# 4. If an agent is unhappy, it moves to an unoccupied cell; otherwise, an agent doesn't move
#
# Despite its simplicity, this model yields results that are often unexpected to those not familiar with it.
#
# ## How to use and modify the code
#
# These excercises are designed around a Mesa template that is given to you to reuse. You are not asked to perform any complex object programming, but instead we ask for understanding of the core features of the Mesa python package. If you want to add functionality or adapt certain features, you will mostly have to modifly the existing template and code the ``Model`` and ``Agent``behavior using standard python code.
#
# Let’s get started.

# %% [markdown]
# # 1. Create the Basic Agent/Model

# %% [markdown]
# ## Setting up the model
#
# To begin writing the model code, we start with two core classes: one for
# the overall model, the other for the agents. The model class holds the
# model-level attributes, manages the agents, and generally handles the
# global level of our model. Each instantiation of the model class will be
# a specific model run. Each model will contain multiple agents, all of
# which are instantiations of the agent class. Both the model and agent
# classes are child classes of Mesa’s generic ``Model`` and ``Agent``
# classes.
#
# ### ``# Agent Initialization``:
#
# Each agent has only two variables:
# - 2D position on the grid (x , y)
# - agent type [0, 1]
#
# (Each agent will also have a unique identifier (i.e., a position), stored in
# the ``pos`` variable. Giving each agent a unique id is a good
# practice when doing agent-based modeling.)
#
# ### ``# Calculate the number of similar neighbours``:
#
# - calculate the number of similar neighbours
# - if the Agent is happy with it's neighbourhood - it stays
#
# ### ``# Move to an empty location if unhappy``:
#
# - if the Agent is unhappy - perform move to better empty cell
# - if at new location there are no neighbors - agent moves
#
# An example of the agent class can look like this:

# %%
import mesa
from mesa import Model, Agent
from mesa.time import RandomActivation
from mesa.space import SingleGrid

print(mesa.__version__)
# Out:
# 2.4.0

# %%
class SchellingAgent(Agent):
    """
    Schelling segregation agent
    """

    def __init__(self, pos, model, agent_type):
        """
        Create a new Schelling agent.

        Args:
           unique_id: Unique identifier for the agent.
           pos: Agent initial location.
           agent_type: Indicator for the agent's type (minority=1, majority=0)
        """
        super().__init__(pos, model)
        self.pos = pos
        self.type = agent_type

    def step(self):
        similar = 0
        for neighbor in self.model.grid.iter_neighbors(self.pos, True):
            if neighbor.type == self.type:
                similar += 1

        # If unhappy, move:
        if similar < self.model.homophily:
            self.model.grid.move_to_empty(self)
        else:
            self.model.happy += 1

# %% [markdown]
# ### ``# Model Initialization``:
#
# There are a number of model-level parameters:
#
# - height and width of the grid
# - density of grid population to define how many agents and empty cells the model contains
# - minority proportion to define proportion of two types of agents on the grid
# - homophily treshold to which the agent is happy with its neighbourhood
#
# ### ``# Create agents``:
#
# - use uniform random numbers to populate the grid based on density parameter
# - use uniform random numbers to selects agent type based on minority proportion
#
# When a new model is started, we want it to populate the grid itself with the defined number of agents with having the given proportion between two groups. Let's implement an example model class:

# %%
class Schelling(Model):
    """
    Model class for the Schelling segregation model.
    
    width: Horizontal axis of the grid which is used together with Height to define the total number of agents in the system.
    height: Vertical axis of the grid which is used together with Width to define the total number of agents in the system.
    density: Define the population density of agent in the system. Floating value from 0 to 1.
    fraction minority: The ratio between blue and red. Blue is represented as the minority while red is represented as the majority. Floating value from 0 to 1. If the value is higher than 0.5, blue will become the majority instead.
    homophily: Define the number of similar neighbors required for the agents to be happy. Integer value range from 0 to 8 since you can only be surrounded by 8 neighbors.
    """

    def __init__(self, width=20, height=20, density=0.8, minority_pc=0.2, homophily=3):
        super().__init__()
        self.width = width
        self.height = height
        self.homophily = homophily

        self.grid = mesa.space.SingleGrid(width, height, torus=True)

        self.happy = 0
        self.datacollector = mesa.DataCollector(
            {"happy": "happy"},  # Model-level count of happy agents
        )

        # Set up agents
        # We use a grid iterator that returns
        # the coordinates of a cell as well as
        # its contents. (coord_iter)
        for _, pos in self.grid.coord_iter():
            if self.random.random() < density:
                agent_type = 1 if self.random.random() < minority_pc else 0
                agent = SchellingAgent(pos, self, agent_type)
                self.grid.place_agent(agent, pos)

        self.datacollector.collect(self)

    def step(self):
        """
        Run one step of the model. If All agents are happy, halt the model.
        """
        self.happy = 0  # Reset counter of happy agents
        self.agents.shuffle().do("step")
        # Must be before data collection.
        self._advance_time()  # Temporary API; will be finalized by Mesa 3.0 release
        # collect data
        self.datacollector.collect(self)

        if self.happy == len(self.agents):
            self.running = False

# %% [markdown]
# # 2. Run the Agent/Model Basic

# %% [markdown]
# ### Running the model
#
# At this point, we have a model which runs.
# You can see for yourself with a few easy lines. If you’ve been working
# in an interactive session, you can create a model object directly.
#
# With that last piece in hand, it’s time for the first rudimentary run of
# the model.
#
# Now let’s create a model with 20 x 20 agents, and run it for 10 steps.

# %% [markdown]
# ### ``# Model parameters``:
#
# - specify all model-level parameters of its __init__ function
# - height and width are given already as 20 x 20, as well as density and minority proportion
# - define homophily threshold

# %%
# Model parameters
model = Schelling(20, 20, 0.98, 0.5, 20)

while model.running:
    model.step()
# Out:
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 0) is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 1) is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 2) is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 3) is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 4) is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 5) is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 6) is being placed with
# place_agent() despite already having the position (0, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 7) is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 8) is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 9) is being placed with
# place_agent() despite already having the position (0, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 10) is being placed with
# place_agent() despite already having the position (0, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 11) is being placed with
# place_agent() despite already having the position (0, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 12) is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 13) is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 14) is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 15) is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 16) is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 17) is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 18) is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 19) is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 0) is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 1) is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 2) is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 3) is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 4) is being placed with
# place_agent() despite already having the position (1, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 5) is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 7) is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 8) is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 9) is being placed with
# place_agent() despite already having the position (1, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 10) is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 11) is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 12) is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 13) is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 14) is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 15) is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 16) is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 18) is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 19) is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 0) is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 1) is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 2) is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 3) is being placed with
# place_agent() despite already having the position (2, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 4) is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 5) is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 6) is being placed with
# place_agent() despite already having the position (2, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 7) is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 8) is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 9) is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 10) is being placed with
# place_agent() despite already having the position (2, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 11) is being placed with
# place_agent() despite already having the position (2, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 12) is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 13) is being placed with
# place_agent() despite already having the position (2, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 14) is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 15) is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 16) is being placed with
# place_agent() despite already having the position (2, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 17) is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 18) is being placed with
# place_agent() despite already having the position (2, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 19) is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 0) is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 1) is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 2) is being placed with
# place_agent() despite already having the position (3, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 3) is being placed with
# place_agent() despite already having the position (3, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 4) is being placed with
# place_agent() despite already having the position (3, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 5) is being placed with
# place_agent() despite already having the position (3, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 6) is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 7) is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 8) is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 9) is being placed with
# place_agent() despite already having the position (3, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 10) is being placed with
# place_agent() despite already having the position (3, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 11) is being placed with
# place_agent() despite already having the position (3, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 12) is being placed with
# place_agent() despite already having the position (3, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 13) is being placed with
# place_agent() despite already having the position (3, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 14) is being placed with
# place_agent() despite already having the position (3, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 15) is being placed with
# place_agent() despite already having the position (3, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 16) is being placed with
# place_agent() despite already having the position (3, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 17) is being placed with
# place_agent() despite already having the position (3, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 18) is being placed with
# place_agent() despite already having the position (3, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 19) is being placed with
# place_agent() despite already having the position (3, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 0) is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 1) is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 2) is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 3) is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 4) is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 5) is being placed with
# place_agent() despite already having the position (4, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 6) is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 7) is being placed with
# place_agent() despite already having the position (4, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 8) is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 9) is being placed with
# place_agent() despite already having the position (4, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 10) is being placed with
# place_agent() despite already having the position (4, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 11) is being placed with
# place_agent() despite already having the position (4, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 12) is being placed with
# place_agent() despite already having the position (4, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 13) is being placed with
# place_agent() despite already having the position (4, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 14) is being placed with
# place_agent() despite already having the position (4, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 15) is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 16) is being placed with
# place_agent() despite already having the position (4, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 17) is being placed with
# place_agent() despite already having the position (4, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 18) is being placed with
# place_agent() despite already having the position (4, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 19) is being placed with
# place_agent() despite already having the position (4, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 0) is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 1) is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 2) is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 3) is being placed with
# place_agent() despite already having the position (5, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 4) is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 5) is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 6) is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 7) is being placed with
# place_agent() despite already having the position (5, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 8) is being placed with
# place_agent() despite already having the position (5, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 9) is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 10) is being placed with
# place_agent() despite already having the position (5, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 11) is being placed with
# place_agent() despite already having the position (5, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 12) is being placed with
# place_agent() despite already having the position (5, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 13) is being placed with
# place_agent() despite already having the position (5, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 14) is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 15) is being placed with
# place_agent() despite already having the position (5, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 16) is being placed with
# place_agent() despite already having the position (5, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 17) is being placed with
# place_agent() despite already having the position (5, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 18) is being placed with
# place_agent() despite already having the position (5, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 19) is being placed with
# place_agent() despite already having the position (5, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 0) is being placed with
# place_agent() despite already having the position (6, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 1) is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 2) is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 3) is being placed with
# place_agent() despite already having the position (6, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 4) is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 5) is being placed with
# place_agent() despite already having the position (6, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 6) is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 7) is being placed with
# place_agent() despite already having the position (6, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 8) is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 9) is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 10) is being placed with
# place_agent() despite already having the position (6, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 11) is being placed with
# place_agent() despite already having the position (6, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 12) is being placed with
# place_agent() despite already having the position (6, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 13) is being placed with
# place_agent() despite already having the position (6, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 14) is being placed with
# place_agent() despite already having the position (6, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 15) is being placed with
# place_agent() despite already having the position (6, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 16) is being placed with
# place_agent() despite already having the position (6, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 17) is being placed with
# place_agent() despite already having the position (6, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 18) is being placed with
# place_agent() despite already having the position (6, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 19) is being placed with
# place_agent() despite already having the position (6, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 0) is being placed with
# place_agent() despite already having the position (7, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 1) is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 2) is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 3) is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 4) is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 5) is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 6) is being placed with
# place_agent() despite already having the position (7, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 7) is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 8) is being placed with
# place_agent() despite already having the position (7, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 10) is being placed with
# place_agent() despite already having the position (7, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 11) is being placed with
# place_agent() despite already having the position (7, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 12) is being placed with
# place_agent() despite already having the position (7, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 13) is being placed with
# place_agent() despite already having the position (7, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# ...
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 15) is being placed with
# place_agent() despite already having the position (17, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 16) is being placed with
# place_agent() despite already having the position (17, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 17) is being placed with
# place_agent() despite already having the position (17, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 18) is being placed with
# place_agent() despite already having the position (17, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 19) is being placed with
# place_agent() despite already having the position (17, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 0) is being placed with
# place_agent() despite already having the position (18, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 1) is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 2) is being placed with
# place_agent() despite already having the position (18, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 4) is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 5) is being placed with
# place_agent() despite already having the position (18, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 6) is being placed with
# place_agent() despite already having the position (18, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 7) is being placed with
# place_agent() despite already having the position (18, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 8) is being placed with
# place_agent() despite already having the position (18, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 9) is being placed with
# place_agent() despite already having the position (18, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 10) is being placed with
# place_agent() despite already having the position (18, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 11) is being placed with
# place_agent() despite already having the position (18, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 12) is being placed with
# place_agent() despite already having the position (18, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 13) is being placed with
# place_agent() despite already having the position (18, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 14) is being placed with
# place_agent() despite already having the position (18, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 15) is being placed with
# place_agent() despite already having the position (18, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 16) is being placed with
# place_agent() despite already having the position (18, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 17) is being placed with
# place_agent() despite already having the position (18, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 18) is being placed with
# place_agent() despite already having the position (18, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 19) is being placed with
# place_agent() despite already having the position (18, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 0) is being placed with
# place_agent() despite already having the position (19, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 1) is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 2) is being placed with
# place_agent() despite already having the position (19, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 3) is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 4) is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 5) is being placed with
# place_agent() despite already having the position (19, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 6) is being placed with
# place_agent() despite already having the position (19, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 7) is being placed with
# place_agent() despite already having the position (19, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 8) is being placed with
# place_agent() despite already having the position (19, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 9) is being placed with
# place_agent() despite already having the position (19, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 10) is being placed with
# place_agent() despite already having the position (19, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 11) is being placed with
# place_agent() despite already having the position (19, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 12) is being placed with
# place_agent() despite already having the position (19, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 13) is being placed with
# place_agent() despite already having the position (19, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 14) is being placed with
# place_agent() despite already having the position (19, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 15) is being placed with
# place_agent() despite already having the position (19, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 16) is being placed with
# place_agent() despite already having the position (19, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 17) is being placed with
# place_agent() despite already having the position (19, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 18) is being placed with
# place_agent() despite already having the position (19, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 19) is being placed with
# place_agent() despite already having the position (19, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 model = Schelling(20, 20, 0.98, 0.5, 20)
#       4 while model.running:
# ----> 5     model.step()
#
# Cell In[5], line 42, in Schelling.step(self)
#      38 """
#      39 Run one step of the model. If All agents are happy, halt the model.
#      40 """
#      41 self.happy = 0  # Reset counter of happy agents
# ---> 42 self.agents.shuffle().do("step")
#      43 # Must be before data collection.
#      44 self._advance_time()  # Temporary API; will be finalized by Mesa 3.0 release
#
# File ~\anaconda3\Lib\site-packages\mesa\agent.py:269, in AgentSet.do(self, method, *args, **kwargs)
#     267     for agentref in self._agents.keyrefs():
#     268         if (agent := agentref()) is not None:
# --> 269             getattr(agent, method)(*args, **kwargs)
#     270 else:
#     271     for agentref in self._agents.keyrefs():
#
# Cell In[3], line 27, in SchellingAgent.step(self)
#      25 # If unhappy, move:
#      26 if similar < self.model.homophily:
# ---> 27     self.model.grid.move_to_empty(self)
#      28 else:
#      29     self.model.happy += 1
#
# File ~\anaconda3\Lib\site-packages\mesa\space.py:553, in _Grid.move_to_empty(self, agent)
#     551 else:
#     552     new_pos = agent.random.choice(sorted(self.empties))
# --> 553 self.remove_agent(agent)
#     554 self.place_agent(agent, new_pos)
#
# File ~\anaconda3\Lib\site-packages\mesa\space.py:1017, in SingleGrid.remove_agent(self, agent)
#    1015 self._grid[x][y] = self.default_val()
#    1016 if self._empties_built:
# -> 1017     self._empties.add(pos)
#    1018 self._empty_mask[agent.pos] = True
#    1019 agent.pos = None
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. Visualize the Agent/Model

# %% [markdown]
# ### At the location ``# Model parameters``:
#
# - specify all model-level parameters of its __init__ function
# - height and width are given already as 20 x 20, as well as density and minority proportion
# - given: homophily treshold 20%

# %%
def get_happy_agents(model):
    """
    Display a text count of how many happy agents there are.
    """
    return f"Happy agents: {model.happy}"


def schelling_draw(agent):
    """
    Portrayal Method for canvas
    """
    if agent is None:
        return
    portrayal = {"Shape": "circle", "r": 0.5, "Filled": "true", "Layer": 0}

    if agent.type == 0:
        portrayal["Color"] = ["#FF0000", "#FF9999"]
        portrayal["stroke_color"] = "#00FF00"
    else:
        portrayal["Color"] = ["#0000FF", "#9999FF"]
        portrayal["stroke_color"] = "#000000"
    return portrayal


canvas_element = mesa.visualization.CanvasGrid(
    portrayal_method=schelling_draw,
    grid_width=20,
    grid_height=20,
    canvas_width=500,
    canvas_height=500,
)
happy_chart = mesa.visualization.ChartModule([{"Label": "happy", "Color": "Black"}])

model_params = {
    "height": 20,
    "width": 20,
    "density": mesa.visualization.Slider(
        name="Agent density", value=0.8, min_value=0.1, max_value=1.0, step=0.1
    ),
    "minority_pc": mesa.visualization.Slider(
        name="Fraction minority", value=0.2, min_value=0.00, max_value=1.0, step=0.05
    ),
    "homophily": mesa.visualization.Slider(
        name="Homophily", value=3, min_value=0, max_value=8, step=1
    )
}

server = mesa.visualization.ModularServer(
    model_cls=Schelling,
    visualization_elements=[canvas_element, get_happy_agents, happy_chart],
    name="Schelling Segregation Model",
    model_params=model_params,
)
# Out:
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 0) is being placed with
# place_agent() despite already having the position (0, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 1) is being placed with
# place_agent() despite already having the position (0, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 2) is being placed with
# place_agent() despite already having the position (0, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 3) is being placed with
# place_agent() despite already having the position (0, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 4) is being placed with
# place_agent() despite already having the position (0, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 5) is being placed with
# place_agent() despite already having the position (0, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 7) is being placed with
# place_agent() despite already having the position (0, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 8) is being placed with
# place_agent() despite already having the position (0, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 11) is being placed with
# place_agent() despite already having the position (0, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 12) is being placed with
# place_agent() despite already having the position (0, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 13) is being placed with
# place_agent() despite already having the position (0, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 14) is being placed with
# place_agent() despite already having the position (0, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 15) is being placed with
# place_agent() despite already having the position (0, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 16) is being placed with
# place_agent() despite already having the position (0, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 17) is being placed with
# place_agent() despite already having the position (0, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 18) is being placed with
# place_agent() despite already having the position (0, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (0, 19) is being placed with
# place_agent() despite already having the position (0, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 0) is being placed with
# place_agent() despite already having the position (1, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 1) is being placed with
# place_agent() despite already having the position (1, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 2) is being placed with
# place_agent() despite already having the position (1, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 3) is being placed with
# place_agent() despite already having the position (1, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 5) is being placed with
# place_agent() despite already having the position (1, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 6) is being placed with
# place_agent() despite already having the position (1, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 7) is being placed with
# place_agent() despite already having the position (1, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 8) is being placed with
# place_agent() despite already having the position (1, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 10) is being placed with
# place_agent() despite already having the position (1, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 11) is being placed with
# place_agent() despite already having the position (1, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 12) is being placed with
# place_agent() despite already having the position (1, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 13) is being placed with
# place_agent() despite already having the position (1, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 14) is being placed with
# place_agent() despite already having the position (1, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 15) is being placed with
# place_agent() despite already having the position (1, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 16) is being placed with
# place_agent() despite already having the position (1, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 17) is being placed with
# place_agent() despite already having the position (1, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 18) is being placed with
# place_agent() despite already having the position (1, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (1, 19) is being placed with
# place_agent() despite already having the position (1, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 0) is being placed with
# place_agent() despite already having the position (2, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 1) is being placed with
# place_agent() despite already having the position (2, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 2) is being placed with
# place_agent() despite already having the position (2, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 4) is being placed with
# place_agent() despite already having the position (2, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 5) is being placed with
# place_agent() despite already having the position (2, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 7) is being placed with
# place_agent() despite already having the position (2, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 8) is being placed with
# place_agent() despite already having the position (2, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 9) is being placed with
# place_agent() despite already having the position (2, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 10) is being placed with
# place_agent() despite already having the position (2, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 12) is being placed with
# place_agent() despite already having the position (2, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 13) is being placed with
# place_agent() despite already having the position (2, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 14) is being placed with
# place_agent() despite already having the position (2, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 15) is being placed with
# place_agent() despite already having the position (2, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 17) is being placed with
# place_agent() despite already having the position (2, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 18) is being placed with
# place_agent() despite already having the position (2, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (2, 19) is being placed with
# place_agent() despite already having the position (2, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 0) is being placed with
# place_agent() despite already having the position (3, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 1) is being placed with
# place_agent() despite already having the position (3, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 6) is being placed with
# place_agent() despite already having the position (3, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 7) is being placed with
# place_agent() despite already having the position (3, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 8) is being placed with
# place_agent() despite already having the position (3, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 11) is being placed with
# place_agent() despite already having the position (3, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 13) is being placed with
# place_agent() despite already having the position (3, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 14) is being placed with
# place_agent() despite already having the position (3, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 15) is being placed with
# place_agent() despite already having the position (3, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 17) is being placed with
# place_agent() despite already having the position (3, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 18) is being placed with
# place_agent() despite already having the position (3, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (3, 19) is being placed with
# place_agent() despite already having the position (3, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 0) is being placed with
# place_agent() despite already having the position (4, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 1) is being placed with
# place_agent() despite already having the position (4, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 2) is being placed with
# place_agent() despite already having the position (4, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 3) is being placed with
# place_agent() despite already having the position (4, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 4) is being placed with
# place_agent() despite already having the position (4, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 6) is being placed with
# place_agent() despite already having the position (4, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 8) is being placed with
# place_agent() despite already having the position (4, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 10) is being placed with
# place_agent() despite already having the position (4, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 12) is being placed with
# place_agent() despite already having the position (4, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 13) is being placed with
# place_agent() despite already having the position (4, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 15) is being placed with
# place_agent() despite already having the position (4, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 17) is being placed with
# place_agent() despite already having the position (4, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (4, 18) is being placed with
# place_agent() despite already having the position (4, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 0) is being placed with
# place_agent() despite already having the position (5, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 1) is being placed with
# place_agent() despite already having the position (5, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 2) is being placed with
# place_agent() despite already having the position (5, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 4) is being placed with
# place_agent() despite already having the position (5, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 5) is being placed with
# place_agent() despite already having the position (5, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 6) is being placed with
# place_agent() despite already having the position (5, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 7) is being placed with
# place_agent() despite already having the position (5, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 9) is being placed with
# place_agent() despite already having the position (5, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 10) is being placed with
# place_agent() despite already having the position (5, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 11) is being placed with
# place_agent() despite already having the position (5, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 12) is being placed with
# place_agent() despite already having the position (5, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 14) is being placed with
# place_agent() despite already having the position (5, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 15) is being placed with
# place_agent() despite already having the position (5, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 16) is being placed with
# place_agent() despite already having the position (5, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 17) is being placed with
# place_agent() despite already having the position (5, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 18) is being placed with
# place_agent() despite already having the position (5, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (5, 19) is being placed with
# place_agent() despite already having the position (5, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 1) is being placed with
# place_agent() despite already having the position (6, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 2) is being placed with
# place_agent() despite already having the position (6, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 4) is being placed with
# place_agent() despite already having the position (6, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 5) is being placed with
# place_agent() despite already having the position (6, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 6) is being placed with
# place_agent() despite already having the position (6, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 8) is being placed with
# place_agent() despite already having the position (6, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 9) is being placed with
# place_agent() despite already having the position (6, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 10) is being placed with
# place_agent() despite already having the position (6, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 11) is being placed with
# place_agent() despite already having the position (6, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 12) is being placed with
# place_agent() despite already having the position (6, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 13) is being placed with
# place_agent() despite already having the position (6, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 14) is being placed with
# place_agent() despite already having the position (6, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 15) is being placed with
# place_agent() despite already having the position (6, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 16) is being placed with
# place_agent() despite already having the position (6, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 17) is being placed with
# place_agent() despite already having the position (6, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 18) is being placed with
# place_agent() despite already having the position (6, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (6, 19) is being placed with
# place_agent() despite already having the position (6, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 1) is being placed with
# place_agent() despite already having the position (7, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 2) is being placed with
# place_agent() despite already having the position (7, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 3) is being placed with
# place_agent() despite already having the position (7, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 4) is being placed with
# place_agent() despite already having the position (7, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 5) is being placed with
# place_agent() despite already having the position (7, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 7) is being placed with
# place_agent() despite already having the position (7, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 8) is being placed with
# place_agent() despite already having the position (7, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 9) is being placed with
# place_agent() despite already having the position (7, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 10) is being placed with
# place_agent() despite already having the position (7, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 11) is being placed with
# place_agent() despite already having the position (7, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 12) is being placed with
# place_agent() despite already having the position (7, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 13) is being placed with
# place_agent() despite already having the position (7, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 14) is being placed with
# place_agent() despite already having the position (7, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 15) is being placed with
# place_agent() despite already having the position (7, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 16) is being placed with
# place_agent() despite already having the position (7, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (7, 17) is being placed with
# place_agent() despite already having the position (7, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 0) is being placed with
# place_agent() despite already having the position (8, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 1) is being placed with
# place_agent() despite already having the position (8, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 2) is being placed with
# place_agent() despite already having the position (8, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 4) is being placed with
# place_agent() despite already having the position (8, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 5) is being placed with
# place_agent() despite already having the position (8, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 6) is being placed with
# place_agent() despite already having the position (8, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 8) is being placed with
# place_agent() despite already having the position (8, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 9) is being placed with
# place_agent() despite already having the position (8, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 11) is being placed with
# place_agent() despite already having the position (8, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 12) is being placed with
# place_agent() despite already having the position (8, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 13) is being placed with
# place_agent() despite already having the position (8, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 14) is being placed with
# place_agent() despite already having the position (8, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 15) is being placed with
# place_agent() despite already having the position (8, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (8, 18) is being placed with
# place_agent() despite already having the position (8, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 0) is being placed with
# place_agent() despite already having the position (9, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 1) is being placed with
# place_agent() despite already having the position (9, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 2) is being placed with
# place_agent() despite already having the position (9, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 3) is being placed with
# place_agent() despite already having the position (9, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 4) is being placed with
# place_agent() despite already having the position (9, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 5) is being placed with
# place_agent() despite already having the position (9, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 6) is being placed with
# place_agent() despite already having the position (9, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 7) is being placed with
# place_agent() despite already having the position (9, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 11) is being placed with
# place_agent() despite already having the position (9, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 12) is being placed with
# place_agent() despite already having the position (9, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (9, 13) is being placed with
# place_agent() despite already having the position (9, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
# ...
# place_agent() despite already having the position (16, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (16, 18) is being placed with
# place_agent() despite already having the position (16, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (16, 19) is being placed with
# place_agent() despite already having the position (16, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 1) is being placed with
# place_agent() despite already having the position (17, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 2) is being placed with
# place_agent() despite already having the position (17, 2). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 3) is being placed with
# place_agent() despite already having the position (17, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 4) is being placed with
# place_agent() despite already having the position (17, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 5) is being placed with
# place_agent() despite already having the position (17, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 8) is being placed with
# place_agent() despite already having the position (17, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 10) is being placed with
# place_agent() despite already having the position (17, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 11) is being placed with
# place_agent() despite already having the position (17, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 13) is being placed with
# place_agent() despite already having the position (17, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 14) is being placed with
# place_agent() despite already having the position (17, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 15) is being placed with
# place_agent() despite already having the position (17, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 16) is being placed with
# place_agent() despite already having the position (17, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 17) is being placed with
# place_agent() despite already having the position (17, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 18) is being placed with
# place_agent() despite already having the position (17, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (17, 19) is being placed with
# place_agent() despite already having the position (17, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 0) is being placed with
# place_agent() despite already having the position (18, 0). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 1) is being placed with
# place_agent() despite already having the position (18, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 3) is being placed with
# place_agent() despite already having the position (18, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 4) is being placed with
# place_agent() despite already having the position (18, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 6) is being placed with
# place_agent() despite already having the position (18, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 7) is being placed with
# place_agent() despite already having the position (18, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 8) is being placed with
# place_agent() despite already having the position (18, 8). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 11) is being placed with
# place_agent() despite already having the position (18, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 13) is being placed with
# place_agent() despite already having the position (18, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 14) is being placed with
# place_agent() despite already having the position (18, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 15) is being placed with
# place_agent() despite already having the position (18, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 16) is being placed with
# place_agent() despite already having the position (18, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 17) is being placed with
# place_agent() despite already having the position (18, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 18) is being placed with
# place_agent() despite already having the position (18, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (18, 19) is being placed with
# place_agent() despite already having the position (18, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 1) is being placed with
# place_agent() despite already having the position (19, 1). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 3) is being placed with
# place_agent() despite already having the position (19, 3). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 4) is being placed with
# place_agent() despite already having the position (19, 4). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 5) is being placed with
# place_agent() despite already having the position (19, 5). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 6) is being placed with
# place_agent() despite already having the position (19, 6). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 7) is being placed with
# place_agent() despite already having the position (19, 7). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 9) is being placed with
# place_agent() despite already having the position (19, 9). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 10) is being placed with
# place_agent() despite already having the position (19, 10). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 11) is being placed with
# place_agent() despite already having the position (19, 11). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 12) is being placed with
# place_agent() despite already having the position (19, 12). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 13) is being placed with
# place_agent() despite already having the position (19, 13). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 14) is being placed with
# place_agent() despite already having the position (19, 14). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 15) is being placed with
# place_agent() despite already having the position (19, 15). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 16) is being placed with
# place_agent() despite already having the position (19, 16). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 17) is being placed with
# place_agent() despite already having the position (19, 17). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 18) is being placed with
# place_agent() despite already having the position (19, 18). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)
# C:\Users\peers\AppData\Local\Temp\ipykernel_16356\1301862913.py:33: UserWarning: Agent (19, 19) is being placed with
# place_agent() despite already having the position (19, 19). In most
# cases, you'd want to clear the current position with remove_agent()
# before placing the agent again.
#   self.grid.place_agent(agent, pos)

# %% [markdown]
# # 4. Run the Agent/Model Visualization
#
# NOTE: Runtime server error is normal and expected when running visualization code below. This visualization code was made for command line execution (not explicitly for Jupyter Notebooks), so we are **forcing** it's use.
#
# Just make sure to increment the port number counter each visualization run, to be able to use it.

# %%
server.port = 8523 # The default 8521 - increase the counter as you run the visalizations
server.launch() # Uncomment to run the visalization
# Out:
# Interface starting at http://127.0.0.1:8523
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 2
#       1 server.port = 8523 # The default 8521 - increase the counter as you run the visalizations
# ----> 2 server.launch()
#
# File ~\anaconda3\Lib\site-packages\mesa_viz_tornado\ModularVisualization.py:407, in ModularServer.launch(self, port, open_browser)
#     405 tornado.autoreload.start()
#     406 try:
# --> 407     tornado.ioloop.IOLoop.current().start()
#     408 except KeyboardInterrupt:
#     409     tornado.ioloop.IOLoop.current().stop()
#
# File ~\anaconda3\Lib\site-packages\tornado\platform\asyncio.py:195, in BaseAsyncIOLoop.start(self)
#     194 def start(self) -> None:
# --> 195     self.asyncio_loop.run_forever()
#
# File ~\anaconda3\Lib\asyncio\base_events.py:596, in BaseEventLoop.run_forever(self)
#     594 """Run until stop() is called."""
#     595 self._check_closed()
# --> 596 self._check_running()
#     597 self._set_coroutine_origin_tracking(self._debug)
#     599 old_agen_hooks = sys.get_asyncgen_hooks()
#
# File ~\anaconda3\Lib\asyncio\base_events.py:588, in BaseEventLoop._check_running(self)
#     586 def _check_running(self):
#     587     if self.is_running():
# --> 588         raise RuntimeError('This event loop is already running')
#     589     if events._get_running_loop() is not None:
#     590         raise RuntimeError(
#     591             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
